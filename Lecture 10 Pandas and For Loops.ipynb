# %% [markdown]
# # Lecture 10 Pandas and For Loops
# - Student Name: Tanish Kochhar
# - Section: A
# - Roll No: 37

# %%
report_database = [
   {
      "class":10,
      "division":"A",
      "teacher":"Zoshua Colah",
      "scores":{
         "student_name":[
            "Jay",
            "Aaryan",
            "Sahil",
            "Riya",
            "Shubh"
         ],
         "math_scores":[
            20,
            56,
            76,
            78,
            90
         ],
         "chemistry_scores":[
            32,
            36,
            78,
            23,
            100
         ],
         "information_technology_scores":[
            34,
            6,
            88,
            100,
            45
         ],
         "physics_scores":[
            6,
            88,
            48,
            90,
            25
         ]
      },
      "emails":{
         "student_name":[
            "Jay",
            "Aaryan",
            "Sahil",
            "Riya",
            "Shubh",
            "Abdul"
         ],
         "student_email":[
            "Jay@gmail.com",
            "Aaryan@gmail.com",
            "Sahil@gmail.com",
            "Riya@gmail.com",
            "Shubh@gmail.com",
            "Abdual@gmail.com"
         ]
      }
   },
   {
      "class":10,
      "division":"B",
      "teacher":"Aayushi Shah",
      "scores":{
         "student_name":[
            "Jai",
            "Aryan",
            "Firoz",
            "Steve",
            "Rhea"
         ],
         "math_scores":[
            32,
            56,
            76,
            78,
            90
         ],
         "chemistry_scores":[
            32,
            56,
            75,
            23,
            10
         ],
         "information_technology_scores":[
            34,
            6,
            48,
            100,
            45
         ],
         "physics_scores":[
            6,
            88,
            58,
            90,
            25
         ]
      },
      "emails":{
         "student_name":[
            "Jai",
            "Aryan",
            "Firoz",
            "Steve",
            "Rhea"
         ],
         "student_email":[
            "Jai@gmail.com",
            "Aryan@gmail.com",
            "Firoz@gmail.com",
            "Steve@gmail.com",
            "Rhea@gmail.com"
         ]
      }
   },
   {
      "class":10,
      "division":"C",
      "teacher":"Rahul Joy",
      "scores":{
         "student_name":[
            "Kareena",
            "Alia",
            "Priyanka",
            "Shahrukh",
            "Salman"
         ],
         "math_scores":[
            22,
            56,
            76,
            78,
            90
         ],
         "chemistry_scores":[
            30,
            56,
            78,
            23,
            100
         ],
         "information_technology_scores":[
            34,
            6,
            98,
            100,
            40
         ],
         "physics_scores":[
            60,
            88,
            58,
            90,
            25
         ]
      },
      "emails":{
         "student_name":[
            "Kareena",
            "Alia",
            "Priyanka",
            "Shahrukh",
            "Salman"
         ],
         "student_email":[
            "Kareena@gmail.com",
            "Alia@gmail.com",
            "Priyanka@gmail.com",
            "Shahrukh@gmail.com",
            "Salman@gmail.com"
         ]
      }
   }
]

# %%
report_database
# Out:
# [{'class': 10,
#   'division': 'A',
#   'teacher': 'Zoshua Colah',
#   'scores': {'student_name': ['Jay', 'Aaryan', 'Sahil', 'Riya', 'Shubh'],
#    'math_scores': [20, 56, 76, 78, 90],
#    'chemistry_scores': [32, 36, 78, 23, 100],
#    'information_technology_scores': [34, 6, 88, 100, 45],
#    'physics_scores': [6, 88, 48, 90, 25]},
#   'emails': {'student_name': ['Jay',
#     'Aaryan',
#     'Sahil',
#     'Riya',
#     'Shubh',
#     'Abdul'],
#    'student_email': ['Jay@gmail.com',
#     'Aaryan@gmail.com',
#     'Sahil@gmail.com',
#     'Riya@gmail.com',
#     'Shubh@gmail.com',
#     'Abdual@gmail.com']}},
#  {'class': 10,
#   'division': 'B',
#   'teacher': 'Aayushi Shah',
#   'scores': {'student_name': ['Jai', 'Aryan', 'Firoz', 'Steve', 'Rhea'],
#    'math_scores': [32, 56, 76, 78, 90],
#    'chemistry_scores': [32, 56, 75, 23, 10],
#    'information_technology_scores': [34, 6, 48, 100, 45],
#    'physics_scores': [6, 88, 58, 90, 25]},
# ...

# %%
# Setup
import pandas as pd

# %%
# Function to accept a list of reports
# Return a mega dataframe (for all divisions)

def get_report_df(report_list):
    
    #Create an empty mega report dataframe
    mega_report_df = pd.DataFrame()
    
    #For Loop
    #For Each Division Dictionary in the report:
    ###################################################
    for div_dictionary in report_list:
    
       # Create a Student Scores DataFrame
        scores_df = pd.DataFrame(div_dictionary["scores"])

        # Create an Emails Dataframe
        emails_df = pd.DataFrame(div_dictionary["emails"])

        #  Merge The Two Dataframes Together
        merged_df = pd.merge(scores_df, emails_df, how = "left", on = ["student_name"])

        #  Add a Class Column
        merged_df["class"] = div_dictionary["class"]                      


        # Add a Division Column
        merged_df["division"] = div_dictionary["division"]

        # Add a Teacher Column
        merged_df["teacher"] = div_dictionary["teacher"]                       

        # Add This Merged Dataframe to Mega Report DataFrame
        mega_report_df = pd.concat([mega_report_df, merged_df], ignore_index = True)
        
        
    #####################################################
        
    mega_report_df ["total_score"] = mega_report_df["physics_scores"] + mega_report_df["chemistry_scores"] + mega_report_df["math_scores"] + mega_report_df["information_technology_scores"]
    mega_report_df ["average_score"] = mega_report_df["total_score"]/4

    mega_report_df.loc[mega_report_df["average_score"]>=35, "status"] = "pass"
    mega_report_df.loc[mega_report_df["average_score"]<=35, "status"] = "fail"
    
    # Return the Mega Report Dataframe
    return mega_report_df

# %%
report_df = get_report_df)report_database)
# Out:
#   File "<ipython-input-48-dbeee6b4459e>", line 1
#     report_df = get_report_df)report_database)
#                              ^
# SyntaxError: unmatched ')'

# %%
report_df = get_report_df(report_database)
report_df
# Out:
#    student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0           Jay           20                32                             34
# 1        Aaryan           56                36                              6
# 2         Sahil           76                78                             88
# 3          Riya           78                23                            100
# 4         Shubh           90               100                             45
# 5           Jai           32                32                             34
# 6         Aryan           56                56                              6
# 7         Firoz           76                75                             48
# 8         Steve           78                23                            100
# 9          Rhea           90                10                             45
# 10      Kareena           22                30                             34
# ...

# %% [markdown]
# # Group By Lecture 11

# %% [markdown]
# ## What is the average total score, average math score, and average physics score?

# %%
avg_score_df = report_df.groupby(["division"]).agg(avg_total_score = ("total_score", "mean"),
                                                   avg_math_score = ("math_scores", "mean"),
                                                   avg_physics_score = ("physics_scores", "mean"))
                                                   
avg_score_df
# Out:
#           avg_total_score  avg_math_score  avg_physics_score
# division
# A                   223.8            64.0               51.4
# B                   205.6            66.4               53.4
# C                   241.6            64.4               64.2

# %% [markdown]
# # What is the total number of students who passed and failed by division?

# %%
pass_fail_df = report_df.groupby(["division", "status"]).agg(total_students = ("status", "count"))
pass_fail_df
# Out:
#                  total_students
# division status
# A        fail                 1
#          pass                 4
# B        fail                 1
#          pass                 4
# C        pass                 5

# %% [markdown]
# ## Give us a report card only with students who received 250 points or above in their total score

# %%
report_250_df = report_df.loc[report_df["total_score"]>=250]
report_250_df
# Out:
#    student_name  math_scores  chemistry_scores  information_technology_scores  \
# 2         Sahil           76                78                             88
# 3          Riya           78                23                            100
# 4         Shubh           90               100                             45
# 7         Firoz           76                75                             48
# 8         Steve           78                23                            100
# 12     Priyanka           76                78                             98
# 13     Shahrukh           78                23                            100
# 14       Salman           90               100                             40
#
#     physics_scores       student_email  class division       teacher  \
# 2               48     Sahil@gmail.com     10        A  Zoshua Colah
# 3               90      Riya@gmail.com     10        A  Zoshua Colah
# ...

# %% [markdown]
# # Give us a report only with students who received 250 points or above in the total score in division A

# %%
report_250_df = report_df.loc[(report_df["total_score"]>=250) & (main_report["division"] == "A")]
report_250_df
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 2        Sahil           76                78                             88
# 3         Riya           78                23                            100
# 4        Shubh           90               100                             45
#
#    physics_scores    student_email  class division       teacher  total_score  \
# 2              48  Sahil@gmail.com     10        A  Zoshua Colah          290
# 3              90   Riya@gmail.com     10        A  Zoshua Colah          291
# 4              25  Shubh@gmail.com     10        A  Zoshua Colah          260
#
#    average_score status
# 2          72.50   pass
# 3          72.75   pass
# 4          65.00   pass

# %% [markdown]
# # Give us a report only with students with A Division or B Division

# %%
report_a_b_df = main_report.loc[(main_report["division"] == "A" ) |  (main_report["division"] == "B")]
report_a_b_df
# Out:
#   student_name  math_scores  chemistry_scores  information_technology_scores  \
# 0          Jay           20                32                             34
# 1       Aaryan           56                36                              6
# 2        Sahil           76                78                             88
# 3         Riya           78                23                            100
# 4        Shubh           90               100                             45
# 5          Jai           32                32                             34
# 6        Aryan           56                56                              6
# 7        Firoz           76                75                             48
# 8        Steve           78                23                            100
# 9         Rhea           90                10                             45
#
#    physics_scores     student_email         class division  total_score  \
# ...

# %% [markdown]
# ## The school wants a report of two teachers: Zoshua Colah and Aayushi Shah. In the report they want to see the average total score and average math score for each teacher.

# %%
zoshua_aayushi_stats_df = main_report.groupby(["teacher"]).agg(avg_total_score = ("total_score", "mean"),
                                                     avg_math_score = ("math_scores", "mean"))
zoshua_aayushi_stats_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-55-798d22d9a1e3> in <module>
# ----> 1 zoshua_aayushi_stats_df = main_report.groupby(["teacher"]).agg(avg_total_score = ("total_score", "mean"),
#       2                                                      avg_math_score = ("math_scores", "mean"))
#       3 zoshua_aayushi_stats_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6715         axis = self._get_axis_number(axis)
#    6716
# -> 6717         return DataFrameGroupBy(
#    6718             obj=self,
#    6719             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %%
pd.melt(main_report,
        id_vara = ["student_name", "class", "division", "teacher"],
        value_vars = ["math_scores", "chemistry_scores", "physics_scores", "information_technology_scores"],
        var_name = "subject", value_name = "score")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-a8b6955d62ad> in <module>
# ----> 1 pd.melt(main_report,
#       2         id_vara = ["student_name", "class", "division", "teacher"],
#       3         value_vars = ["math_scores", "chemistry_scores", "physics_scores", "information_technology_scores"],
#       4         var_name = "subject", value_name = "score")
#
# TypeError: melt() got an unexpected keyword argument 'id_vara'

# %%
melted_df.loc[melted_df["subject"] == "physics_scores", "subject"] = "physics"
melted_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-831eb6e5451d> in <module>
# ----> 1 melted_df.loc[melted_df["subject"] == "physics_scores", "subject"] = "physics"
#       2 melted_df
#
# NameError: name 'melted_df' is not defined

# %%
melted_df = pd.melt(main_report,
                    id_vars = ["student_name", "class", "division", "teacher"]
                    value_vars = ["math_scores", "chemistry_scores", "physics_scores", "information_technology_scores"],
                    var_name = "subject", value_name = "score")

melted_df.loc[melted_df["subject"] == "physics_scores", "subject",] = "physics"
melted_df.loc[melted_df["subject"] == "math_scores", "subject"] = "Maths"
# Out:
#   File "<ipython-input-58-375eb8ddc51c>", line 3
#     value_vars = ["math_scores", "chemistry_scores", "physics_scores", "information_technology_scores"],
#     ^
# SyntaxError: invalid syntax
